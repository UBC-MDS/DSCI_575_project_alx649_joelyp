# %% [markdown]
# ## Milestone 1 EDA

# %% [markdown]
# ### Read Raw Data
#
# NOTE: Before running this, ensure that the `Patio_Lawn_and_Garden` dataset has been unpacked into `data/raw`.

# %%
import pandas as pd
import csv, json, time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create Samples of the Data
#
# This is to view a small sample of the data so that we know what we are working with.

# %%
reviews_df = pd.read_json("../data/raw/Patio_Lawn_and_Garden.jsonl", lines = True, chunksize = 100)
metadata_df = pd.read_json("../data/raw/meta_Patio_Lawn_and_Garden.jsonl", lines = True, chunksize = 100)

# %%
first_reviews = next(reviews_df)
first_reviews.to_json("../data/processed/Patio_Lawn_and_Garden_sample.jsonl",orient='records', indent=4)
first_meta = next(metadata_df)
first_meta.to_json("../data/processed/meta_Patio_Lawn_and_Garden_sample.jsonl",orient='records', indent=4)
# Out:
# /tmp/ipykernel_1226310/3922114877.py:2: Pandas4Warning: The default 'epoch' date format is deprecated and will be removed in a future version, please use 'iso' date format instead.
#   first_reviews.to_json("../data/processed/Patio_Lawn_and_Garden_sample.jsonl",orient='records', indent=4)

# %%
first_reviews.head()
# Out:
#    rating                                              title  \
# 0       1  Someone’s return? Arrived broken in several pl...
# 1       1                                     Arrived broken
# 2       1                                      Disappointing
# 3       3  Cute style but just ok- don't buy more than 1 ...
# 4       5  Seriously I have tried just about everything. ...
#
#                                                 text  \
# 0  Seriously. Not my best month with Amazon. Open...
# 1  The chair wouldn't fold out properly. The foot...
# 2  Bought this on a Cyber Monday deal and I'm so ...
# 3  Bought these because of the unique look. I pur...
# 4  Seriously I have tried just about everything. ...
#
#                                               images        asin parent_asin  \
# 0  [{'small_image_url': 'https://images-na.ssl-im...  B00KGVWNRG  B07CL2CD4D
# 1                                                 []  B00I4Z8GCM  B0C6HJPJXL
# 2                                                 []  B01CHG9MXA  B01CHG9MXA
# 3                                                 []  B004BK1DL0  B004BK1DL0
# 4                                                 []  B004CSWPS6  B004CSWPS6
#
#                         user_id               timestamp  helpful_vote  \
# 0  AFKZENTNBQ7A7V7UXW5JJI6UGRYQ 2021-04-21 00:33:51.473             0
# 1  AGGZ357AO26RQZVRLGU4D4N52DZQ 2022-08-23 13:32:57.742             0
# 2  AGGZ357AO26RQZVRLGU4D4N52DZQ 2016-12-13 21:46:16.000             0
# 3  AGKASBHYZPGTEPO6LWZPVJWB2BVA 2022-05-21 23:03:26.096             1
# 4  AGCI7FAH4GL5FI65HYLKWTMFZ2CQ 2016-09-17 20:36:07.000             0
#
#    verified_purchase
# 0              False
# 1               True
# 2               True
# 3               True
# 4              False

# %%
first_meta.head()
# Out:
#   main_category                                              title  \
# 0   Amazon Home  AISEN Carburetor AIR Filter Tune UP KIT for C1...
# 1   Amazon Home  Orbit 57946 B-hyve Smart 6-Zone Indoor/Outdoor...
# 2   Amazon Home  KafePross Merry Monogram M Decorative Garden F...
# 3   Amazon Home  Kwik Covers 8' Rectangle Plastic Table Covers ...
# 4   Amazon Home  Agfabric Plant Cover Warm Worth Frost Blanket ...
#
#    average_rating  rating_number  \
# 0             3.8              8
# 1             4.5          12815
# 2             4.1              9
# 3             4.5            346
# 4             3.1              3
#
#                                             features  \
# 0  [Fits for Echo PB-2155 Leaf Debris Blower ES-2...
# 1  [WELCOME TO B-HYVE: Looking to get a smart spr...
# 2  [Mini garden flag (size: 12.5" x 18") are made...
# 3  [Kwik-Covers are hygienic table covers and dis...
# 4  [SUITABLE SIZE Perfect for Greenhouse size 90'...
#
#                                          description  price  \
# 0                                                 []  18.26
# 1  [From the manufacturer, Orbit is North America...  99.17
# 2  [KafePross have a lot of flag design, there ar...   9.99
# 3  [8' x 30" Kwik-Cover is a lightweight, elastic...  35.95
# 4  [Agfabric Plant cover made with high quality s...    NaN
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
# 2  [{'thumb': 'https://m.media-amazon.com/images/...
# 3  [{'thumb': 'https://m.media-amazon.com/images/...
# 4  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos        store  \
# 0                                                 []        AISEN
# 1  [{'title': 'Most affordable Smart Home Sprinkl...        Orbit
# 2                                                 []    KafePross
# 3  [{'title': 'Take a closer look at the table co...  Kwik Covers
# 4                                                 []     Agfabric
#
#                                           categories  \
# 0  [Patio, Lawn & Garden, Outdoor Power Tools, Re...
# 1  [Patio, Lawn & Garden, Gardening & Lawn Care, ...
# 2       [Patio, Lawn & Garden, Outdoor Décor, Flags]
# 3  [Patio, Lawn & Garden, Patio Furniture & Acces...
# 4  [Patio, Lawn & Garden, Gardening & Lawn Care, ...
#
#                                              details parent_asin  \
# 0  {'Package Dimensions': '4.57 x 3.03 x 1.34 inc...  B074C2TTV8
# 1  {'Product Dimensions': '3 x 9 x 8 inches', 'It...  B0BCZK8S44
# 2  {'Package Dimensions': '9.37 x 6.14 x 0.47 inc...  B08K362CRS
# 3  {'Brand': 'Kwik Covers', 'Color': 'Orange', 'M...  B06XVX7YQT
# 4  {'Package Dimensions': '15.98 x 12.99 x 4.02 i...  B01I9NNPYW
#
#    bought_together
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# ### Load and Clean 'Reviews' Raw JSONL file

# %%
REVIEWS_IN  = '../data/raw/Patio_Lawn_and_Garden.jsonl'
REVIEWS_OUT = '../data/processed/reviews_clean.csv'

KEEP_REVIEW_COLS = ['parent_asin', 'rating', 'title', 'text', 'helpful_vote']

def extract_medium_image(images):                                            # 'images'=list of dicts with different URLs =>  only want one image /review
    if not isinstance(images, list):                        
        return None
    for img in images:
        if isinstance(img, dict) and img.get('attachment_type') != 'IMAGE':     # attachment_type IMAGE => not product photos => skip [
            return img.get('medium')
    return None

start = time.time()                                                               # set timer 
with open(REVIEWS_IN, 'r', encoding='utf-8') as fin, \
    open(REVIEWS_OUT, 'w', newline='', encoding='utf-8') as fout:                  # open compressed input for streaming + csv for output
    writer = None                                                                   # csv writer init 
    kept, dropped = 0, 0                                                             # counters

    for line in fin:
        record = json.loads(line)                                                      # each line=JSON object => parse into a dict
        if not record.get('verified_purchase', False):                                  # drop unverified purchases => likely to be spam or other
            dropped += 1
            continue
        if not record.get('text', '').strip():                                            # drop reviews without  text => not useful 
            dropped += 1
            continue
        row = {col: record.get(col) for col in KEEP_REVIEW_COLS}                            # pull only listed columns
        row['image_url'] = extract_medium_image(record.get('images', []))                  # replace full images list with single medium URL    
        if writer is None:                                                                # initialise csv writer on first valid row 
            writer = csv.DictWriter(fout, fieldnames=row.keys())
            writer.writeheader()
        writer.writerow(row)
        kept += 1

        if (kept + dropped) % 1_500_000 == 0:                                          # heartbeat every 1.5M lines for pulse-check :) 
            elapsed = time.time() - start
            print(f"  {kept + dropped:,} lines processed in {elapsed:.1f}s")

elapsed = time.time() - start
print(f"\nDone in {elapsed:.1f}s  |  Kept: {kept:,}  |  Dropped: {dropped:,}")
# Out:
#   1,500,000 lines processed in 32.1s
#   3,000,000 lines processed in 63.5s
#   4,500,000 lines processed in 94.2s
#   6,000,000 lines processed in 125.3s
#   7,500,000 lines processed in 155.8s
#   10,500,000 lines processed in 217.6s
#   12,000,000 lines processed in 248.0s
#   13,500,000 lines processed in 278.7s
#   15,000,000 lines processed in 309.2s
#
# Done in 339.3s  |  Kept: 15,495,259  |  Dropped: 994,788

# %% [markdown]
# ### Load and Clean 'Meta' Raw JSONL file

# %%
META_IN = '../data/raw/meta_Patio_Lawn_and_Garden.jsonl'
META_OUT = '../data/processed/meta_clean.csv'

KEEP_META_COLS = ['parent_asin', 'title', 'average_rating', 'rating_number',
                  'features', 'description', 'price', 'store', 'details']

def extract_medium_image_meta(images):
    if not isinstance(images, list) or not images:
        return None
    first = images[0]
    return first.get('medium') if isinstance(first, dict) else None

start = time.time()
with open(META_IN, 'r', encoding='utf-8') as fin, \
     open(META_OUT, 'w', newline='', encoding='utf-8') as fout:
    writer = None
    kept, dropped = 0, 0

    for line in fin:
        record = json.loads(line)
        if not record.get('title', '').strip():
            dropped += 1
            continue
        row = {col: record.get(col) for col in KEEP_META_COLS}
        row['image_url'] = extract_medium_image_meta(record.get('images', []))
        if writer is None:
            writer = csv.DictWriter(fout, fieldnames=row.keys())
            writer.writeheader()
        writer.writerow(row)
        kept += 1

        if (kept + dropped) % 100_000 == 0:                                    # heartbeat every 100K lines
            elapsed = time.time() - start
            print(f"  {kept + dropped:,} lines processed in {elapsed:.1f}s")

elapsed = time.time() - start
print(f"\nDone in {elapsed:.1f}s  |  Kept: {kept:,}  |  Dropped: {dropped:,}")
# Out:
#   100,000 lines processed in 11.9s
#   200,000 lines processed in 22.8s
#   300,000 lines processed in 34.1s
#   400,000 lines processed in 44.6s
#   500,000 lines processed in 54.6s
#   600,000 lines processed in 64.4s
#   700,000 lines processed in 74.1s
#   800,000 lines processed in 83.7s
#
# Done in 90.0s  |  Kept: 851,875  |  Dropped: 32
